# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize
from scipy import integrate
from scipy import interpolate

# %%
#path = "/Users/argelia/Documents/Trabajo/TrabajoNestor/Data/Blok_McGaugh_Rubin_2001/"
#data = np.loadtxt(path+"ESO3020120.dat")
path="/Users/namh2/OneDrive/Documentos/DOCTORADO/AJUSTES Y ERRORES LANE-EMDEN/Blok_McGaugh_Rubin_2001/"
data=np.loadtxt(path+"U11557.dat")
#path="/Users/namh2/Downloads/anterior/ajusteTOV/"
#data=np.loadtxt(path+"datos.txt")

# %%
RCr_data = np.array([row[1] for row in data])# galactocentric distance [kpc]
RCv_data = np.array([row[5] for row in data])# rotation velocity [km/s]
RCev_data = np.array([row[6] for row in data])# error in rotation velocity [km/s]

# %%
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
plt.ylabel(r'$v_{c}(r)$[km/s]')
plt.xlabel("r[kpc]")
# Out:
# Text(0.5, 0, 'r[kpc]')

# %%
def Integrate(func,x0,y0,x,h):
    # Finds value of y for a given x using step size h 
    # and initial value y0 at x0.
    def RK4(func,x0,y0,h):
        K0 = h*func(x0,y0)
        K1 = h*func(x0 + 0.5*h, y0 + 0.5*K0)
        K2 = h*func(x0 + 0.5*h, y0 + 0.5*K1)
        K3 = h*func(x0 + h, y0 + K2)
        return (K0 + 2.*K1 + 2.*K2 + K3)/6.
    X = []
    Y = []
    X.append(x0)
    Y.append(y0)
    #while x0 < x:
    while y0[0] < 1.09900000000000:
    #while y0[0]>0.99:
        y0 = y0 + RK4(func,x0,y0,h) #update next value of y
        x0 = x0 + h #update next value of x
        X.append(x0)
        Y.append(y0)
    return np.array(X),np.array(Y)

# %%
def rhs(x,y):
    dy=np.zeros(2)
    dy[0]=4*np.pi*Gm*x**2*(y[1]/K)
    dy[1]=-Gp*y[0]/x**2*(y[1]/K)
    return dy

# %%
def model(data,v,X):
    V = []
    x=X
    RC=v*np.sqrt(G)
    Int_l = interpolate.interp1d(x,RC)   #,fill_value='extrapolate')
    for i in range(len(data)):
        if data[i] < x[-1]:
            v=Int_l(data[i])
            V.append(v)
        else:
            #v=0.
            v=np.sqrt(G*Y[:,0][-1]/(data[i]))
            V.append(v)
    return V,RC

# %%
def Xi2(RCv_data,RCv_teo,RCev_data):
    xi=np.sum((RCv_data-RCv_teo)**2./(RCev_data)**2.)
    return xi

# %%
Gm=2.5188027*10**(-3)
Gp=0.499246*10**(-6)
G=4.258*10**(4)
Gv=1.24*10**(5)
y0=np.zeros(2)
h=0.001
x0=0.00001

# %%
#K_min=2*10**(-7)
#K_max=0.5*10**(-6)
K_min=2.001*10**(-8)
K_max=8.*10**(-8)
Kvec=np.linspace(K_min,K_max,100)
#p_0min=5.*10**(-12)
#p_0max=7.*10**(-6)
p_0min=2.001*10**(-8)
p_0max=6.5*10**(-8)
p_0=np.linspace(p_0min,p_0max,100)

# %%
y0[0]=0.
y0[1]=p_0[0]
K=K_min

# %%
X,Y=Integrate(rhs,x0,y0,10.,h)
v=np.sqrt(Y[:,0]/X)
plt.plot(X,v)

# %%
V,RC=model(RCr_data,v,X)
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
plt.plot(RCr_data,V)
plt.ylabel(r'$V$[km/s]')
plt.xlabel("R[kpc]")
# Out:
# Text(0.5, 0, 'R[kpc]')

# %%
# %%time
xi_minimo=10000
xi = np.zeros((len(p_0),len(Kvec)))
for l in range(0,len(Kvec)):
    K=Kvec[l]
    for i in range(0,len(p_0)):
        x0=0.00001
        y0[0]=0.
        y0[1]=p_0[i]
        X,Y=Integrate(rhs,x0,y0,10.,h)
        v=np.sqrt(Y[:,0]/X)
        V,RC=model(RCr_data,v,X)
        xi[i,l]=Xi2(RCv_data,V,RCev_data)
        if (xi[i,l] < xi_minimo):
            xi_minimo=xi[i,l]
            p0_minimo=p_0[i]
            K_minimo=Kvec[l]
# Out:
# Wall time: 35min 37s

# %%
print(xi_minimo)
print(K_minimo)
print(p0_minimo)
print(V)
print(RC)
print(X)
plt.plot(X,RC)
# Out:
# 0.4609011530441297
# 5.576161616161616e-08
# 3.3643333333333335e-08
# [array(5.72748154), array(17.08409579), array(29.9582169), array(40.4833982), array(51.98749168), array(61.08379397), array(70.73882493), array(78.18120085), array(84.87098097), 86.8884494071969]
# [0.00000000e+00 1.92964335e-02 3.84018288e-02 ... 8.94152342e+01
#  8.94248967e+01 8.94345574e+01]
# [1.00000e-05 1.01000e-03 2.01000e-03 ... 5.85001e+00 5.85101e+00
#  5.85201e+00]

# %%
plt.plot(X,Y[:,1])

# %%
plt.plot(X,Y[:,0])

# %%
y0[0]=0.
y0[1]=p0_minimo
K=K_minimo

# %%
X,Y=Integrate(rhs,x0,y0,10.,h)
v=np.sqrt(Y[:,0]/X)
V,RC=model(RCr_data,v,X)
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
p=plt.plot(RCr_data,V)
plt.ylabel(r'$V$[km/s]')
plt.xlabel("R[kpc]")
# Out:
# Text(0.5, 0, 'R[kpc]')

# %%
xi2=np.zeros((len(p_0),len(Kvec)))
for i in range(0,len(p_0)):
    for j in range (0,len(Kvec)):
        xi2_minimo=10000
        if (xi[i,j] < xi2_minimo):
            xi2_minimo=xi[i,j]
            xi2[i,j]=xi[i,j]

# %%
x,y = np.meshgrid(p_0,Kvec)
fig = plt.figure(dpi=100)
plt.contourf(x,y,xi2,100,cmap='viridis')
plt.xlabel(r'$p_0$')
plt.ylabel(r'$K$')
plt.colorbar();

# %%
xicl = np.zeros((len(p_0),len(Kvec)))
for l in range(0,len(p_0)):
    for j in range(0,len(Kvec)):
        #if ((xin[l,j] ) <= 0.02029568018541897+3.53):
        if ((xi2[l,j] ) <= 2.):
            xicl[l,j]=xi2[l,j]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6720/2020901760.py in <module>
# ----> 1 xicl = np.zeros((len(p_0),len(Kvec)))
#       2 for l in range(0,len(p_0)):
#       3     for j in range(0,len(Kvec)):
#       4         #if ((xin[l,j] ) <= 0.02029568018541897+3.53):
#       5         if ((xi2[l,j] ) <= 5.):
#
# NameError: name 'np' is not defined

# %%
x,y = np.meshgrid(p_0,Kvec)
fig = plt.figure(dpi=100)
plt.contourf(x,y,xicl,200,cmap='viridis')
plt.xlabel(r'$p_0$')
plt.ylabel(r'$K$')
plt.colorbar();
