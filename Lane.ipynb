# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize
from scipy import integrate
from scipy import interpolate

# %%
#path = "/Users/argelia/Documents/Trabajo/TrabajoNestor/Data/Blok_McGaugh_Rubin_2001/"
#data = np.loadtxt(path+"ESO3020120.dat")
path="/Users/namh2/Downloads/anterior/ajusteTOV/"
data=np.loadtxt(path+"datos.txt")

# %%
RCr_data = np.array([row[1] for row in data])# galactocentric distance [kpc]
RCv_data = np.array([row[5] for row in data])# rotation velocity [km/s]
RCev_data = np.array([row[6] for row in data])# error in rotation velocity [km/s]

# %%
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
plt.ylabel(r'$v_{c}(r)$[km/s]')
plt.xlabel("r[kpc]")
# Out:
# Text(0.5, 0, 'r[kpc]')

# %%
def Integrate(func,x0,y0,x,h):
    # Finds value of y for a given x using step size h 
    # and initial value y0 at x0.
    def RK4(func,x0,y0,h):
        K0 = h*func(x0,y0)
        K1 = h*func(x0 + 0.5*h, y0 + 0.5*K0)
        K2 = h*func(x0 + 0.5*h, y0 + 0.5*K1)
        K3 = h*func(x0 + h, y0 + K2)
        return (K0 + 2.*K1 + 2.*K2 + K3)/6.
    X = []
    Y = []
    X.append(x0)
    Y.append(y0)
    #while x0 < x:
    while y0[0] > 0.01:
    #while y0[0] > 1.e-3:
         # Count number of iterations using step size or
        #h = min(h,x - x0)# step height h
        y0 = y0 + RK4(func,x0,y0,h)#update next value of y
        x0 = x0 + h#update next value of x
        X.append(x0)
        Y.append(y0)
    return np.array(X),np.array(Y)

# %%
def rhs(x,y):
    dy=np.zeros(2)
    dy[0]=y[1]
    dy[1]=-2/x*y[1]-y[0]**n
    return dy

# %%
y0=np.zeros(2)
h=0.01
x0=0.0001
y0[0]=1.
y0[1]=0.
n=4.7
X,Y=Integrate(rhs,x0,y0,10.,h)

# %%
plt.plot(X,Y[:,0])

# %%
G_s=4.785e-7
K=7e-7
p_0=5.56e-10
g=1.2
rho_s=1.66e-22*(3.08e21)**3/2e43
rho_0=(p_0/K)**(1./g)*rho_s
al=((n+1)*1./3*1./G_s*K**(2./g)*p_0**(1.-2./g))**(0.5)

# %%
al
# Out:
# 18.469882372375817

# %%
rho_s
# Out:
# 0.24251032959999996

# %%
m=4.*np.pi*al**3*X*X*(-Y[:,1])*rho_0

# %%
plt.plot(al*X,Y[:,0])

# %%
plt.plot(al*X,m)

# %%
v=np.sqrt(4.258*10**(4)*m/(al*X))

# %%
plt.plot(al*X,v)

# %%
plt.plot(al*X,v)
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
plt.xlim(0,12)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
def model(data,X,Y):
    V = []
    RC=np.sqrt(G*Y[:,0]/X)
    Int_l = interpolate.interp1d(X,RC)#,fill_value='extrapolate')
    for i in range(len(data)):
        if data[i] < X[-1]:
            v=Int_l(data[i])
            V.append(v)
        else:
            v=np.sqrt(G*Y[:,0][-1]/(data[i]))
            V.append(v)
    return V,RC

# %%
al
# Out:
# 18.469882372375817

# %%
def Xi2(RCv_data,RCv_teo,RCev_data):
    xi=np.sum((RCv_data-RCv_teo)**2./(RCev_data)**2.)
    return xi

# %%
Gs=4.785*10**(-7)
G=4.258*10**(4)
y0=np.zeros(2)
h=0.01

# %%
#K=1.*10**(-6)
#g=1.7
K_min=7*10**(-7)
K_max=1.1*10**(-6)
K_min=3*10**(-7)
K_max=1.5*10**(-6)
Kvec=np.linspace(K_min,K_max,20)
p_0min=5.56*10**(-10)
p_0max=5.98*10**(-10)
p_0=np.linspace(p_0min,p_0max,15)
g_min=1.2
g_max=1.7
gvec=np.linspace(g_min,g_max,15)

# %%
xi_minimo=1000
xi = np.zeros((len(p_0),len(gvec),len(Kvec)))
for l in range(0,len(Kvec)):
    K=Kvec[l]
    for j in range(0,len(gvec)):
        g=gvec[j]
        for i in range(0,len(p_0)):
            x0=0.0001
            y0[0]=0
            y0[1]=p_0[i]
            X,Y=Integrate(rhs,x0,y0,p_0[i],h)
            V,RC=model(RCr_data,X,Y)
            xi[i,j,l]=Xi2(RCv_data,V,RCev_data)
            if (xi[i,j,l] < xi_minimo):
                xi_minimo=xi[i,j,l]
                p0_minimo=p_0[i]
                g_minimo=gvec[j]
                K_minimo=Kvec[l]

# %%
print(xi_minimo)
print(K_minimo)
print(p0_minimo)
print(g_minimo)
# Out:
# 1.6683983676381873
# 3e-07
# 5.77e-10
# 1.45

# %%
print(xi_minimo)
print(K_minimo)
print(p0_minimo)
print(g_minimo)
# Out:
# 1.6658965260096452
# 3.631578947368421e-07
# 5.800000000000001e-10
# 1.5

# %%
xi_p0 = np.zeros((len(gvec),len(Kvec)))
for j in range(0,len(gvec)):
    for l in range(0,len(Kvec)):
        xi_p0minimo=10000
        for i in range(0,len(p_0)):  
            if (xi[i,j,l] < xi_p0minimo):
                xi_p0minimo=xi[i,j,l]
                xi_p0[j,l]=xi_p0minimo
min_p0=100000
for j in range(0,len(gvec)):
    for l in range(0,len(Kvec)):
        if (xi_p0[j,l] < min_p0):
            min_p0=xi_p0[j,l]
            min_gp0=gvec[j]
            min_Kp0=Kvec[l]
print(min_p0)
print(min_Kp0)
print(min_gp0)
# Out:
# 1.6683983676381873
# 3e-07
# 1.45

# %%
xi_K = np.zeros((len(gvec),len(p_0)))
for j in range(0,len(gvec)):
    for l in range(0,len(p_0)):
        xi_Kminimo=10000
        for i in range(0,len(Kvec)):  
            if (xi[l,j,i] < xi_Kminimo):
                xi_Kminimo=xi[l,j,i]
                xi_K[l,j]=xi_Kminimo
min_K=100000
for j in range(0,len(gvec)):
    for l in range(0,len(p_0)):
        if (xi_K[l,j] < min_K):
            min_K=xi_K[l,j]
            min_gK=gvec[j]
            min_p0K=p_0[l]
print(min_K)
print(min_p0K)
print(min_gK)
# Out:
# 1.6683983676381873
# 5.77e-10
# 1.45

# %%
xi_g = np.zeros((len(Kvec),len(p_0)))
for j in range(0,len(Kvec)):
    for l in range(0,len(p_0)):
        xi_gminimo=10000
        for i in range(0,len(gvec)):  
            if (xi[l,i,j] < xi_gminimo):
                xi_gminimo=xi[l,i,j]
                xi_g[l,j]=xi_gminimo
min_g=10000
for j in range(0,len(Kvec)):
    for l in range(0,len(p_0)):
        if (xi_g[l,j] < min_g):
            min_g=xi_g[l,j]
            min_Kg=Kvec[j]
            min_p0g=p_0[l]
print(min_g)
print(min_Kg)
print(min_p0g)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-7dcfc57c13ef> in <module>
#       6             if (xi[l,i,j] < xi_gminimo):
#       7                 xi_gminimo=xi[l,i,j]
# ----> 8                 xi_g[l,j]=xi_gminimo
#       9 min_g=10000
#      10 for j in range(0,len(Kvec)):
#
# IndexError: index 15 is out of bounds for axis 1 with size 15

# %%
x,y = np.meshgrid(Kvec,gvec)
fig = plt.figure(dpi=100)
plt.contourf(y,x,xi_p0,25,cmap='viridis')
plt.xlabel(r'$g$')
plt.ylabel(r'$K$')
plt.colorbar();

# %%
x,y = np.meshgrid(gvec,p_0)
fig = plt.figure(dpi=100)
plt.contourf(y,x,xi_K,25,cmap='viridis')
plt.xlabel(r'$p_0$')
plt.ylabel(r'$g$')
plt.colorbar();

# %%
x,y = np.meshgrid(p_0,Kvec)
fig = plt.figure(dpi=100)
plt.contourf(y,x,xi_g,25,cmap='viridis')
plt.xlabel(r'$K$')
plt.ylabel(r'$p_0$')
plt.colorbar();

# %%
x,y = np.meshgrid(gvec,p_0)
fig = plt.figure(dpi=100)
plt.contourf(y,x,xi,25,cmap='viridis')
plt.xlabel(r'$p_0$')
plt.ylabel(r'$g$')
plt.colorbar();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-a2147b6b8ce7> in <module>
#       1 x,y = np.meshgrid(gvec,p_0)
#       2 fig = plt.figure(dpi=100)
# ----> 3 plt.contourf(y,x,xi,25,cmap='viridis')
#       4 plt.xlabel(r'$p_0$')
#       5 plt.ylabel(r'$g$')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in contourf(data, *args, **kwargs)
#    2575 @_copy_docstring_and_deprecators(Axes.contourf)
#    2576 def contourf(*args, data=None, **kwargs):
# -> 2577     __ret = gca().contourf(
#    2578         *args, **({"data": data} if data is not None else {}),
#    2579         **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6338     def contourf(self, *args, **kwargs):
#    6339         kwargs['filled'] = True
# -> 6340         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6341         self._request_autoscale_view()
#    6342         return contours
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, *args, **kwargs)
#     814         self._transform = transform
#     815
# --> 816         kwargs = self._process_args(*args, **kwargs)
#     817         self._process_levels()
#     818
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/contour.py in _process_args(self, corner_mask, *args, **kwargs)
#    1428             self._corner_mask = corner_mask
#    1429
# -> 1430             x, y, z = self._contour_args(args, kwargs)
#    1431
#    1432             _mask = ma.getmask(z)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1486             args = args[1:]
#    1487         elif Nargs <= 4:
# -> 1488             x, y, z = self._check_xyz(args[:3], kwargs)
#    1489             args = args[3:]
#    1490         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1517
#    1518         if z.ndim != 2:
# -> 1519             raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1520         if z.shape[0] < 2 or z.shape[1] < 2:
#    1521             raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#
# TypeError: Input z must be 2D, not 3D

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"},dpi=100)
surf = ax.plot_surface(y,x,xi,cmap='viridis',linewidth=0,antialiased=False)
ax.set_xlabel(r'$p_0$')
ax.set_ylabel(r'$g')
ax.set_zlabel(r'$\chi^2$')
# Out:
# Text(0.5, 0, '$\\chi^2$')

# %%
plt.plot(p_0,xi)
# Out:
# [<matplotlib.lines.Line2D at 0x7fa92aaa3250>,
#  <matplotlib.lines.Line2D at 0x7fa92aaa3460>,
#  <matplotlib.lines.Line2D at 0x7fa92aaa33a0>,
#  <matplotlib.lines.Line2D at 0x7fa92aaa3790>,
#  <matplotlib.lines.Line2D at 0x7fa92aaa3c70>]

# %%
xi_minimo
# Out:
# 2.72877094781021

# %%
p0_minimo
# Out:
# 5.826666666666667e-10

# %%
g_minimo
# Out:
# 1.71

# %%
xi_minimo
# Out:
# 2.72877094781021

# %%
K_minimo
# Out:
# 9.666666666666666e-07

# %%
x0=0.0001
K=K_minimo
g=g_minimo
y0[1]=p0_minimo
X,Y=Integrate(rhs,x0,y0,p0_minimo,h)
V,RC=model(RCr_data,X,Y)

# %%
plt.plot(X,RC)
plt.plot(RCr_data,V)
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
2.417196664395324
7e-07
5.86e-10
1.6428571428571428
2.5582023553186675
8e-07
5.89e-10
1.6714285714285713
x0=0.0001
K=8*10**(-7)
p_0=5.89e-10
g=1.6714285714285713
y0[0]=0
y0[1]=p_0
X,Y=Integrate(rhs,x0,y0,p0_minimo,h)
V,RC=model(RCr_data,X,Y)
Xi2(RCv_data,V,RCev_data)
# Out:
# 2.5582023553186675

# %%
plt.plot(X,Y[:,1])

# %%
plt.plot(X,RC)
plt.plot(RCr_data,V)
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
# Out:
# <ErrorbarContainer object of 3 artists>
