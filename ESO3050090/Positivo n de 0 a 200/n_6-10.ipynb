# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize
from scipy import integrate
from scipy import interpolate

# %%
path="/Users/namh2/OneDrive/Documentos/DOCTORADO/AJUSTES Y ERRORES LANE-EMDEN/Blok_McGaugh_Rubin_2001/"
data=np.loadtxt(path+"ESO3050090.dat")

# %%
RCr_data = np.array([row[1] for row in data])# galactocentric distance [kpc]
RCv_data = np.array([row[5] for row in data])# rotation velocity [km/s]
RCev_data = np.array([row[6] for row in data])# error in rotation velocity [km/s]

# %%
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
plt.ylabel(r'$v_{c}(r)$[km/s]')
plt.xlabel("r[kpc]")
# Out:
# Text(0.5, 0, 'r[kpc]')

# %%
def Integrate(func,x0,y0,x,h):
    # Finds value of y for a given x using step size h 
    # and initial value y0 at x0.
    def RK4(func,x0,y0,h):
        K0 = h*func(x0,y0)
        K1 = h*func(x0 + 0.5*h, y0 + 0.5*K0)
        K2 = h*func(x0 + 0.5*h, y0 + 0.5*K1)
        K3 = h*func(x0 + h, y0 + K2)
        return (K0 + 2.*K1 + 2.*K2 + K3)/6.
    X = []
    Y = []
    X.append(x0)
    Y.append(y0)
    #while x0 < x:
    while y0[0] >0.21:
    #while y0[0] > 1.e-3:
         # Count number of iterations using step size or
        #h = min(h,x - x0)# step height h
        y0 = y0 + RK4(func,x0,y0,h)#update next value of y
        x0 = x0 + h#update next value of x
        X.append(x0)
        Y.append(y0)
    return np.array(X),np.array(Y)

# %%
def rhs(x,y):
    dy=np.zeros(2)
    dy[0]=y[1]
    dy[1]=-2/x*y[1]-y[0]**n
    return dy

# %%
y0=np.zeros(2)
h=0.005
x0=0.0001
y0[0]=1.
y0[1]=0.

# %%
def model(data,X,v,alpha,rhoc):
    V = []
    r = alpha*X
    RC = alpha*np.sqrt(G*rhoc)*v
    Int_l = interpolate.interp1d(r,RC)#,fill_value='extrapolate')
    for i in range(len(data)):
        if data[i] < r[-1]:
            v=Int_l(data[i])
            V.append(v)
        else:
            v=0.
            V.append(v)
    return V

# %%
def Xi2(RCv_data,RCv_teo,RCev_data):
    xi=np.sum((RCv_data-RCv_teo)**2./(RCev_data)**2.)
    return xi

# %%
G=4.258*10**(4)
n_min=6.0
n_max=10.
alpha_min=1.5
alpha_max=4.5
rhoc_min=0.0022
rhoc_max=0.0028
n_vec=np.linspace(n_min,n_max,20)
alpha_vec=np.linspace(alpha_min,alpha_max,50)
rhoc_vec=np.linspace(rhoc_min,rhoc_max,50)

# %%
n=6.
X,Y=Integrate(rhs,x0,y0,10.,h)
m=-4.*np.pi*X**2*Y[:,1]
v=np.sqrt(m/X)
plt.plot(X,v)
print(n_vec[0])
# Out:
# 6.0

# %%
V=model(RCr_data,X,v,1.4,0.002)
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
plt.plot(RCr_data,V)
plt.ylabel(r'$V$[km/s]')
plt.xlabel("R[kpc]")
# Out:
# Text(0.5, 0, 'R[kpc]')

# %%
xi_minimo=1000
xi = np.zeros((len(n_vec),len(alpha_vec),len(rhoc_vec)))
for i in range(0,len(n_vec)):
    n=n_vec[i]
    X,Y=Integrate(rhs,x0,y0,10.,h)
    m=-4.*np.pi*X**2*Y[:,1]
    v=np.sqrt(m/X)
    for l in range(0,len(alpha_vec)):
        for j in range(0,len(rhoc_vec)):
            V=model(RCr_data,X,v,alpha_vec[l],rhoc_vec[j])
            xi[i,l,j]=Xi2(RCv_data,V,RCev_data)
            if (xi[i,l,j] < xi_minimo):
                xi_minimo=xi[i,l,j]
                n_minimo=n_vec[i]
                alpha_minimo=alpha_vec[l]
                rhoc_minimo=rhoc_vec[j]

# %%
print(n_minimo)
print(alpha_minimo)
print(rhoc_minimo)
print(xi_minimo)
# Out:
# 10.0
# 3.3979591836734695
# 0.0025061224489795917
# 0.8949199285341971

# %%
plt.plot(X,Y[:,0])

# %%
n=n_minimo
X,Y=Integrate(rhs,x0,y0,10.,h)
m=-4.*np.pi*X**2*Y[:,1]
v=np.sqrt(m/X)
V=model(RCr_data,X,v,alpha_minimo,rhoc_minimo)
print(n)
# Out:
# 10.0

# %%
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
plt.plot(RCr_data,V)
plt.ylabel(r'$V$[km/s]')
plt.xlabel("R[kpc]")
# Out:
# Text(0.5, 0, 'R[kpc]')

# %%
xin=np.zeros((len(alpha_vec),len(rhoc_vec)))
for l in range(0,len(alpha_vec)):
    for j in range(0,len(rhoc_vec)):
        xin_minimo=10000
        for i in range(0,len(n_vec)):
            if (xi[i,l,j] < xin_minimo):
                xin_minimo = xi[i,l,j]
                xin[l,j]=xi[i,l,j]

# %%
x,y = np.meshgrid(rhoc_vec,alpha_vec)
fig = plt.figure(dpi=100)
plt.contourf(x,y,xin,200,cmap='viridis')
plt.xlabel(r'$\rho$')
plt.ylabel(r'$\alpha$')
plt.colorbar();

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"},dpi=100)
surf = ax.plot_surface(x,y,xin,cmap='viridis',linewidth=0,antialiased=False)
ax.set_xlabel(r'$\rho$')
ax.set_ylabel(r'$\alpha$')
ax.set_zlabel(r'$\chi^2$')
# Out:
# Text(0.5, 0, '$\\chi^2$')

# %%
xicl = np.zeros((len(alpha_vec),len(rhoc_vec)))
for l in range(0,len(alpha_vec)):
    for j in range(0,len(rhoc_vec)):
        #if ((xin[l,j] ) <= 0.02029568018541897+3.53):
        if ((xin[l,j] ) <= 1.0):
            xicl[l,j]=xin[l,j]

# %%
x,y = np.meshgrid(rhoc_vec,alpha_vec)
fig = plt.figure(dpi=100)
plt.contourf(x,y,xicl,100,cmap='viridis')
plt.xlabel(r'$\rho$')
plt.ylabel(r'$\alpha$')
plt.colorbar();

# %%
long=1000000
gama_vec=np.zeros(long)
kapa_vec=np.zeros(long)
xi_vec=np.zeros(long)
xir=np.zeros((len(n_vec),len(alpha_vec)))
k=0
for i in range(0,len(n_vec)):
    for l in range(0,len(alpha_vec)):
        xir_minimo=100000
        for j in range(0,len(rhoc_vec)):
            if (xi[i,l,j] < xir_minimo):             
                xir_minimo = xi[i,l,j]
                rhom=rhoc_vec[j]
        xir[i,l]=xir_minimo
        if ((xir_minimo) <=0.2247083232871626+3.53):
            gama_vec[k]=1./n_vec[i]
            kapa_vec[k]=alpha_vec[l]**2*rhom**(1.-1./n_vec[i])/(n_vec[i]+1.)
            #kapa_vec[k]=alpha_vec[l]
            xi_vec[k]=xir_minimo
            k=k+1

# %%
print(k)
vec1=np.zeros(k)
vec2=np.zeros(k)
vec3=np.zeros(k)
for i in range(0,len(vec1)):
    vec1[i]=gama_vec[i]
    vec2[i]=kapa_vec[i]
    vec3[i]=xi_vec[i]
# Out:
# 549

# %%
np.savetxt("gakap_n_6_10.txt",np.transpose([vec1,vec2,vec3]))

# %%
xir=np.zeros((len(n_vec),len(alpha_vec)))
xit=100000
for i in range(0,len(n_vec)):
    for l in range(0,len(alpha_vec)):
        xir_minimo=10000
        for j in range(0,len(rhoc_vec)):
            if (xi[i,l,j] < xir_minimo):
                xir_minimo = xi[i,l,j]
                xir[i,l]=xir_minimo

# %%
x,y = np.meshgrid(alpha_vec,n_vec)
fig = plt.figure(dpi=100)
plt.contourf(x,y,xir,25,cmap='viridis')
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$n$')
plt.colorbar();

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"},dpi=100)
surf = ax.plot_surface(x,y,xir,cmap='viridis',linewidth=0,antialiased=False)
ax.set_xlabel(r'$\alpha$')
ax.set_ylabel(r'$n$')
ax.set_zlabel(r'$\chi^2$')
# Out:
# Text(0.5, 0, '$\\chi^2$')

# %%
xicl = np.zeros((len(n_vec),len(alpha_vec)))
for l in range(0,len(n_vec)):
    for j in range(0,len(alpha_vec)):
        if ((xir[l,j]) <=  0.014203039910330128+3.53):
            xicl[l,j]=xir[l,j]

# %%
x,y = np.meshgrid(alpha_vec,n_vec)
fig = plt.figure(dpi=100)
plt.contourf(x,y,xicl,10,cmap='viridis')
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$n$')
plt.colorbar();
