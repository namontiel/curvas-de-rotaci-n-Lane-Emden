# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize
from scipy import integrate
from scipy import interpolate

# %%
path="/Users/namh2/OneDrive/Documentos/DOCTORADO/AJUSTES Y ERRORES LANE-EMDEN/Blok_McGaugh_Rubin_2001/"
data=np.loadtxt(path+"ESO4880049.dat")

# %%
RCr_data = np.array([row[1] for row in data])# galactocentric distance [kpc]
RCv_data = np.array([row[5] for row in data])# rotation velocity [km/s]
RCev_data = np.array([row[6] for row in data])# error in rotation velocity [km/s]

# %%
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
plt.ylabel(r'$v_{c}(r)$[km/s]')
plt.xlabel("r[kpc]")
# Out:
# Text(0.5, 0, 'r[kpc]')

# %%
def Integrate(func,x0,y0,x,h):
    # Finds value of y for a given x using step size h 
    # and initial value y0 at x0.
    def RK4(func,x0,y0,h):
        K0 = h*func(x0,y0)
        K1 = h*func(x0 + 0.5*h, y0 + 0.5*K0)
        K2 = h*func(x0 + 0.5*h, y0 + 0.5*K1)
        K3 = h*func(x0 + h, y0 + K2)
        return (K0 + 2.*K1 + 2.*K2 + K3)/6.
    X = []
    Y = []
    X.append(x0)
    Y.append(y0)
    #while x0 < x:
    while y0[0] > 0.8:
    #while y0[0] > 1.e-3:
         # Count number of iterations using step size or
        #h = min(h,x - x0)# step height h
        y0 = y0 + RK4(func,x0,y0,h)#update next value of y
        x0 = x0 + h#update next value of x
        X.append(x0)
        Y.append(y0)
    return np.array(X),np.array(Y)

# %%
def rhs(x,y):
    dy=np.zeros(2)
    dy[0]=y[1]
    dy[1]=-2/x*y[1]-y[0]**n
    return dy

# %%
y0=np.zeros(2)
h=0.01
x0=0.0001
y0[0]=1.
y0[1]=0.

# %%
def model(data,X,v,alpha,rhoc):
    V = []
    r = alpha*X
    RC = alpha*np.sqrt(G*rhoc)*v
    Int_l = interpolate.interp1d(r,RC)#,fill_value='extrapolate')
    for i in range(len(data)):
        if data[i] < r[-1]:
            v=Int_l(data[i])
            V.append(v)
        else:
            v=np.sqrt(G*m[-1]*alpha**3*rhoc/(data[i]))
            V.append(v)
    return V

# %%
def Xi2(RCv_data,RCv_teo,RCev_data):
    xi=np.sum((RCv_data-RCv_teo)**2./(RCev_data)**2.)
    return xi

# %%
G=4.258*10**(4)
n_min=345
n_max=347
alpha_min=16.345575
alpha_max=16.412020
rhoc_min=0.00875
rhoc_max=0.00877
n_vec=np.linspace(n_min,n_max,10)
alpha_vec=np.linspace(alpha_min,alpha_max,10)
rhoc_vec=np.linspace(rhoc_min,rhoc_max,10)

# %%
xi_minimo=1000
xi = np.zeros((len(n_vec),len(alpha_vec),len(rhoc_vec)))
for i in range(0,len(n_vec)):
    n=n_vec[i]
    X,Y=Integrate(rhs,x0,y0,10.,h)
    m=-4.*np.pi*X**2*Y[:,1]
    v=np.sqrt(m/X)
    for l in range(0,len(alpha_vec)):
        for j in range(0,len(rhoc_vec)):
            V=model(RCr_data,X,v,alpha_vec[l],rhoc_vec[j])
            xi[i,l,j]=Xi2(RCv_data,V,RCev_data)
            if (xi[i,l,j] < xi_minimo):
                xi_minimo=xi[i,l,j]
                n_minimo=n_vec[i]
                alpha_minimo=alpha_vec[l]
                rhoc_minimo=rhoc_vec[j]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13448/1714978149.py in <module>
#       3 for i in range(0,len(n_vec)):
#       4     n=n_vec[i]
# ----> 5     X,Y=Integrate(rhs,x0,y0,10.,h)
#       6     m=-4.*np.pi*X**2*Y[:,1]
#       7     v=np.sqrt(m/X)
#
# ~\AppData\Local\Temp/ipykernel_13448/4150291284.py in Integrate(func, x0, y0, x, h)
#      17          # Count number of iterations using step size or
#      18         #h = min(h,x - x0)# step height h
# ---> 19         y0 = y0 + RK4(func,x0,y0,h)#update next value of y
#      20         x0 = x0 + h#update next value of x
#      21         X.append(x0)
#
# ~\AppData\Local\Temp/ipykernel_13448/4150291284.py in RK4(func, x0, y0, h)
#       7         K2 = h*func(x0 + 0.5*h, y0 + 0.5*K1)
#       8         K3 = h*func(x0 + h, y0 + K2)
# ----> 9         return (K0 + 2.*K1 + 2.*K2 + K3)/6.
#      10     X = []
#      11     Y = []
#
# KeyboardInterrupt:

# %%
print(n_minimo)
print(alpha_minimo)
print(rhoc_minimo)
print(xi_minimo)
# Out:
# 77.33333333333333
# 9.921052631578947
# 0.004368421052631579
# 0.02096330474636141

# %%
V=model(RCr_data,X,v,alpha_minimo,rhoc_minimo)

# %%
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
plt.plot(RCr_data,V)
plt.ylabel(r'$V$[km/s]')
plt.xlabel("R[kpc]")
# Out:
# Text(0.5, 0, 'R[kpc]')

# %%
xin_minimo=1000
xin=np.zeros((len(alpha_vec),len(rhoc_vec)))
for l in range(0,len(alpha_vec)):
    for j in range(0,len(rhoc_vec)):
        for i in range(0,len(n_vec)):
            if (xi[i,l,j] < xin_minimo):
                xin[l,j]=xi[i,l,j]

# %%
x,y = np.meshgrid(alpha_vec,rhoc_vec)
fig = plt.figure(dpi=100)
plt.contourf(y,x,xin,25,cmap='viridis')
#plt.xlabel(r'$g$')
#plt.ylabel(r'$K$')
plt.colorbar();

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"},dpi=100)
surf = ax.plot_surface(y,x,xin,cmap='viridis',linewidth=0,antialiased=False)
ax.set_xlabel(r'$p_c$')
ax.set_ylabel(r'$\alpha$')
ax.set_zlabel(r'$\chi^2$')
# Out:
# Text(0.5, 0, '$\\chi^2$')

# %%
xicl = np.zeros((len(alpha_vec),len(rhoc_vec)))
for l in range(0,len(alpha_vec)):
    for j in range(0,len(rhoc_vec)):
        if ((xin[l,j] - xi_minimo) <= .2):
            xicl[l,j]=xin[l,j]

# %%
x,y = np.meshgrid(alpha_vec,rhoc_vec)
fig = plt.figure(dpi=100)
plt.contourf(y,x,xicl,25,cmap='viridis')
#plt.xlabel(r'$g$')
#plt.ylabel(r'$K$')
plt.colorbar();
