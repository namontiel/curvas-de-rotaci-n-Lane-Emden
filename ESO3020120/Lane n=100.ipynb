# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize
from scipy import integrate
from scipy import interpolate

# %%
path = "/Users/namh2/OneDrive/Documentos/DOCTORADO/GALAXIAS MUESTRA/Blok_McGaugh_Rubin_2001/Blok_McGaugh_Rubin_2001/"
data = np.loadtxt(path+"ESO3020120.dat")

# %%
RCr_data = np.array([row[1] for row in data])# galactocentric distance [kpc]
RCv_data = np.array([row[5] for row in data])# rotation velocity [km/s]
RCev_data = np.array([row[6] for row in data])# error in rotation velocity [km/s]

# %%
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
plt.ylabel(r'$v_{c}(r)$[km/s]')
plt.xlabel("r[kpc]")
# Out:
# Text(0.5, 0, 'r[kpc]')

# %%
def Integrate(func,x0,y0,x,h):
    # Finds value of y for a given x using step size h 
    # and initial value y0 at x0.
    def RK4(func,x0,y0,h):
        K0 = h*func(x0,y0)
        K1 = h*func(x0 + 0.5*h, y0 + 0.5*K0)
        K2 = h*func(x0 + 0.5*h, y0 + 0.5*K1)
        K3 = h*func(x0 + h, y0 + K2)
        return (K0 + 2.*K1 + 2.*K2 + K3)/6.
    X = []
    Y = []
    X.append(x0)
    Y.append(y0)
    #while x0 < x:
    while y0[0] > 1.e-9:
    #while y0[0] > 1.e-3:
         # Count number of iterations using step size or
        #h = min(h,x - x0)# step height h
        y0 = y0 + RK4(func,x0,y0,h)#update next value of y
        x0 = x0 + h#update next value of x
        X.append(x0)
        Y.append(y0)
    return np.array(X),np.array(Y)

# %%
def rhs(x,y):
    dy=np.zeros(2)
    dy[0]=y[1]
    dy[1]=-2/x*y[1]+y[0]**n
    return dy

# %%
y0=np.zeros(2)
h=0.01
x0=0.0001
y0[0]=1.
y0[1]=0.

# %%
def rvmaxima(v,r,vmax):
    for i in range(len(v)):
        if v[i] == vmax:
            rvmax=r[i]
    return rvmax

# %%
def model(data,X,v,alpha,rhoc):
    V = []
    r = alpha*X
    RC = alpha*np.sqrt(G*rhoc)*v
    Int_l = interpolate.interp1d(r,RC)#,fill_value='extrapolate')
    for i in range(len(data)):
        if data[i] < r[-1]:
            v=Int_l(data[i])
            V.append(v)
        else:
            v=np.sqrt(G*m[-1]*alpha**3*rhoc/(data[i]))
            V.append(v)
    return V

# %%
def Xi2(RCv_data,RCv_teo,RCev_data):
    xi=np.sum((RCv_data-RCv_teo)**2./(RCev_data)**2.)
    return xi

# %%
n=-2
X,Y=Integrate(rhs,x0,y0,10.,h)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9956/1511398004.py in <module>
#       1 n=-2
# ----> 2 X,Y=Integrate(rhs,x0,y0,10.,h)
#
# ~\AppData\Local\Temp/ipykernel_9956/3455014575.py in Integrate(func, x0, y0, x, h)
#      19         y0 = y0 + RK4(func,x0,y0,h)#update next value of y
#      20         x0 = x0 + h#update next value of x
# ---> 21         X.append(x0)
#      22         Y.append(y0)
#      23     return np.array(X),np.array(Y)
#
# MemoryError:

# %%
m=4.*np.pi*X**2*Y[:,1]
v=np.sqrt(m/X)
print(m)
# Out:
# [0.]

# %%
Vmax=max(RCv_data)
vmax=max(v)
RVmax=rvmaxima(RCv_data,RCr_data,Vmax)
rvmax=rvmaxima(v,X,vmax)
print(Vmax)
print(vmax)
print(RVmax)
print(rvmax)
# Out:
# 86.3
# 0.0
# 10.0
# 0.0001

# %%
G=4.258*10**(4)
alpha=RVmax/rvmax
rhoc=Vmax**2/vmax**2*1./(alpha**2*G)
print(alpha)
print(rhoc)
# Out:
# 100000.0
# inf
# C:\Users\namh2\AppData\Local\Temp/ipykernel_6988/2547118837.py:3: RuntimeWarning: divide by zero encountered in double_scalars
#   rhoc=Vmax**2/vmax**2*1./(alpha**2*G)

# %%
alpha_min=0.1
alpha_max=50.
rhoc_min=5e-5
rhoc_max=2e-2
alpha_vec=np.linspace(alpha_min,alpha_max,20)
rhoc_vec=np.linspace(rhoc_min,rhoc_max,20)

# %%
xi_minimo=1000
xi = np.zeros((len(alpha_vec),len(rhoc_vec)))
for l in range(0,len(alpha_vec)):
    for j in range(0,len(rhoc_vec)):
        V=model(RCr_data,X,v,alpha_vec[l],rhoc_vec[j])
        xi[l,j]=Xi2(RCv_data,V,RCev_data)
        if (xi[l,j] < xi_minimo):
            xi_minimo=xi[l,j]
            alpha_minimo=alpha_vec[l]
            rhoc_minimo=rhoc_vec[j]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6988/3750578952.py in <module>
#       3 for l in range(0,len(alpha_vec)):
#       4     for j in range(0,len(rhoc_vec)):
# ----> 5         V=model(RCr_data,X,v,alpha_vec[l],rhoc_vec[j])
#       6         xi[l,j]=Xi2(RCv_data,V,RCev_data)
#       7         if (xi[l,j] < xi_minimo):
#
# ~\AppData\Local\Temp/ipykernel_6988/3475380766.py in model(data, X, v, alpha, rhoc)
#       3     r = alpha*X
#       4     RC = alpha*np.sqrt(G*rhoc)*v
# ----> 5     Int_l = interpolate.interp1d(r,RC)#,fill_value='extrapolate')
#       6     for i in range(len(data)):
#       7         if data[i] < r[-1]:
#
# ~\AppData\Roaming\Python\Python39\site-packages\scipy\interpolate\_interpolate.py in __init__(***failed resolving arguments***)
#     570
#     571         if len(self.x) < minval:
# --> 572             raise ValueError("x and y arrays must have at "
#     573                              "least %d entries" % minval)
#     574
#
# ValueError: x and y arrays must have at least 2 entries

# %%
print(alpha_minimo)
print(rhoc_minimo)
print(xi_minimo)
# Out:
# 34.83839732888147
# 0.000749415692821369
# 1000

# %%
V=model(RCr_data,X,v,alpha_minimo,rhoc_minimo)

# %%
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
plt.plot(RCr_data,V)
plt.ylabel(r'$V$[km/s]')
plt.xlabel("R[kpc]")
# Out:
# Text(0.5, 0, 'R[kpc]')

# %%
x,y = np.meshgrid(alpha_vec,rhoc_vec)
fig = plt.figure(dpi=100)
plt.contourf(y,x,xi,25,cmap='viridis')
#plt.xlabel(r'$g$')
#plt.ylabel(r'$K$')
plt.colorbar();

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"},dpi=100)
surf = ax.plot_surface(y,x,xi,cmap='viridis',linewidth=0,antialiased=False)
ax.set_xlabel(r'$p_c$')
ax.set_ylabel(r'$\alpha$')
ax.set_zlabel(r'$\chi^2$')
# Out:
# Text(0.5, 0, '$\\chi^2$')

# %%
xicl = np.zeros((len(alpha_vec),len(rhoc_vec)))
for l in range(0,len(alpha_vec)):
    for j in range(0,len(rhoc_vec)):
        if ((xi[l,j] - xi_minimo) <= 40):
            xicl[l,j]=xi[l,j]

# %%
x,y = np.meshgrid(alpha_vec,rhoc_vec)
fig = plt.figure(dpi=100)
plt.contourf(y,x,xicl,25,cmap='viridis')
#plt.xlabel(r'$g$')
#plt.ylabel(r'$K$')
plt.colorbar();
